# %% [markdown]
# <a href="https://colab.research.google.com/github/aishuse/Decision-Trees/blob/master/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/DT.csv')
df
# Out:
#    instance      a1    a2      a3 outcome
# 0         1   true   hot    high       no
# 1         2   true   hot    high       no
# 2         3  false   hot    high      yes
# 3         4  false   cool  normal     yes
# 4         5  false   cool  normal     yes
# 5         6   true   cool   high       no
# 6         7   true   hot    high       no
# 7         8   true   hot   normal     yes
# 8         9  false   cool  normal     yes
# 9        10  false   cool   high      yes

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['a1'] = le.fit_transform(df['a1'])
df['a2'] = le.fit_transform(df['a2'])
df['a3'] = le.fit_transform(df['a3'])
df
# Out:
#    instance  a1  a2  a3 outcome
# 0         1   1   1   0      no
# 1         2   1   1   0      no
# 2         3   0   1   0     yes
# 3         4   0   0   1     yes
# 4         5   0   0   1     yes
# 5         6   1   0   0      no
# 6         7   1   1   0      no
# 7         8   1   1   1     yes
# 8         9   0   0   1     yes
# 9        10   0   0   0     yes

# %%
df.drop('instance', axis=1, inplace=True)
df
# Out:
#    a1  a2  a3 outcome
# 0   1   1   0      no
# 1   1   1   0      no
# 2   0   1   0     yes
# 3   0   0   1     yes
# 4   0   0   1     yes
# 5   1   0   0      no
# 6   1   1   0      no
# 7   1   1   1     yes
# 8   0   0   1     yes
# 9   0   0   0     yes

# %%
x = df.iloc[:,:-1]
x
# Out:
#    a1  a2  a3
# 0   1   1   0
# 1   1   1   0
# 2   0   1   0
# 3   0   0   1
# 4   0   0   1
# 5   1   0   0
# 6   1   1   0
# 7   1   1   1
# 8   0   0   1
# 9   0   0   0

# %%
x.shape
# Out:
# (10, 3)

# %%
y = df.iloc[:,-1]
y
# Out:
# 0     no
# 1     no
# 2    yes
# 3    yes
# 4    yes
# 5     no
# 6     no
# 7    yes
# 8    yes
# 9    yes
# Name: outcome, dtype: object

# %%
y.shape
# Out:
# (10,)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(x,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
tree.plot_tree(clf, filled=True, feature_names=['a1','a2','a3'], class_names=['No','Yes'])
plt.show()

# %% [markdown]
# # IRIS DATASET

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import pandas as pd
import numpy as np
df = pd.read_csv('gdrive/My Drive/Colab Notebooks/Iris.csv')
df
# Out:
# Mounted at /content/gdrive
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df1 = df.drop(['Id'], axis=1)
df1
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
x = df1.iloc[:,:-1].values
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
y = df1.iloc[:,-1].values
y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(x,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
tree.plot_tree(clf, filled=True)
plt.show()
